# %% [markdown]
# # Building goSPL inputs for a global plate-motion model
#
# This notebook prepares the input files required to run a **global** `gospl` landscape evolution simulation that includes **horizontal plate motion**. It builds an unstructured spherical (UGRID/Voronoi) mesh at a chosen resolution, interpolates paleo-environmental fields (elevation, plate velocities, precipitation) from regular `netcdf` grids onto that mesh, derives the **vertical tectonic forcing** from successive paleo-elevation maps, and finally writes the compressed `.npz` mesh and forcing files that `gospl` reads.
#
# By the end you obtain an `init.vtk` mesh you can inspect in Paraview plus `mesh.npz` and `forcing250.npz` ready to feed into a `gospl` run. No surface-process equations are solved here, this is purely input generation.
#
# **Tools used:** [jigsaw](https://github.com/dengwirda/jigsaw) / [UXarray](https://uxarray.readthedocs.io) for meshing, `xarray` for the regular grids, and the helper routines in `scripts/umeshFcts.py`.

# %% [markdown]
# The next cell selects the target resolution and triggers the mesh build. `buildGlobalMeshSimple` produces a quasi-uniform global Voronoi mesh; choosing `widthCell` is a trade-off between spatial detail and node count (and therefore runtime), see the table above.
#
# | Parameter | Symbol | Value | Physical meaning |
# | --------- | ------ | ----- | ---------------- |
# | `widthCell` | $\Delta x$ | 30 | Target mesh cell width in km (mean edge length); coarser values give fewer nodes and faster models |
# | `input_path` | – | `input_30` | Output directory where the generated mesh files are stored |

# %% [markdown]
# jigsaw writes its outputs into the working directory. The next cell moves all the generated mesh artefacts (`.jig`, `.msh`, `.nc`, log files) into `input_path` so the project stays organised.

# %%
import os
import shutil
import numpy as np
import xarray as xr

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from scripts import umeshFcts as ufcts

# %% [markdown]
# # Create a global mesh for goSPL
#
# Create an unstructured grid for a given cell width. The method relies on the UXarray and jigsaw libraries.
#
# **In case where the mesh already exists it will not be recreated.**
#
# Spherical mesh resolution km
#
# | cell_width | edge_min  | edge_max | edge_mean | nodeNb |
# | ---------- | ----------  | ---------- | ---------- | ---------- |
# | 5 | 1.1 | 4.5 | 2.8 | 23632811 |
# | 8 |  1.8 | 7.2 | 4.6  | 9236387 |
# | 10 | 2.2 | 8.9 | 5.7 | 5912778 |
# | 15 | 3.3 | 13.1 | 8.6 | 2629742 |
# | 20 | 4.5 | 18 | 11.5 | 1480168 |
# | 25 | 5.6 | 22.4 | 14.4 | 947701 |
# | 30 | 6.8 | 26.4 | 17.2 | 658525 |
# | 35 | 8 | 30.5 | 20.1 |  484009 |

# %%
widthCell = 30
input_path = "input_"+str(widthCell) 

# Build the mesh
ufcts.buildGlobalMeshSimple(widthCell, input_path)

# %% [markdown]
# Run shell commands for file or mesh management.

# %% [markdown]
# The `data/250.nc` regular grid stores the fields below (the suffix `250` refers to the reconstruction time step, e.g. 250 Ma). We keep only the variables `gospl` needs:
#
# | Variable | Symbol | Units | Physical meaning |
# | -------- | ------ | ----- | ---------------- |
# | `h` | $z$ | m | Paleo-elevation / bathymetry |
# | `vx`, `vy`, `vz` | $\mathbf{v}$ | m/yr | Cartesian components of the horizontal plate-motion (advection) velocity |
# | `rain` | $P$ | m/yr | Precipitation rate driving fluvial erosion |

# %%
# !mv mesh.jig mesh.log mesh.msh mesh-MESH.msh mesh-HFUN.msh mesh_triangles.nc CellWidthVsLatLon.nc $input_path

# %% [markdown]
# ### Interpolating the regular grid onto the UGRID mesh
#
# Here we open the UGRID mesh built above and use `inter2UGRID` to bilinearly interpolate each regular-grid field onto the unstructured cell centres (`type='face'`). Results are written one file per variable into `var_path` (`vars_30/`) under the name `step_250`, then re-opened as `data_ds` for the checks that follow.

# %% [markdown]
# ## Map variables on the UGRID
#
# We will now map global variables on this unstructured grid. In goSPL, typical variables would be:
#
# - elevation (in m)
# - vertical and horizontal tectonic forcing (displacement rates in m/yr)
# - precipitation (in m/yr)
# - dynamic topography (in m/yr)
#
# Usually they will be provided in the form of `netcdf` or `geotiff` files. In both cases, the `xarray` or `rioxarray` libraries will allow you to open those files conveniently.
#
# > Here we will use a netcdf grid containing all of these variables (except dynamic topography) for a give time interval.

# %% [markdown]
# ### Reading the mesh geometry and connectivity
#
# We extract the Cartesian coordinates of the Voronoi cell centres (`ucoords`, the goSPL nodes) and the triangulation connectivity (`ufaces`, converted to 0-based indexing). We also report the edge-length statistics (in km) so you can confirm the realised resolution matches the requested `widthCell`.

# %%
# Loading the nc regular file
ncgrid = xr.open_dataset('data/250.nc')

# %% [markdown]
# ### Optional: export the Voronoi mesh for Paraview
#
# Set `saveVoro = True` to write the full Voronoi (dual) mesh as a `.vtp` file using the MPAS Paraview extractor. This is useful to inspect the cell layout as a wireframe; it is disabled by default because the export can be slow for high-resolution meshes.

# %% [markdown]
# In case the file contains more variables than the ones you need for goSPL, you can select only the necessary ones:

# %%
ncgrid = ncgrid[['h','vx','vy','vz','rain']]
ncgrid

# %% [markdown]
# Loading the UGRID file

# %%
# Loading the UGRID file
ufile = input_path+'/mesh_'+str(widthCell)+'km.nc'
mapds = xr.open_dataset(ufile) 

# Perform the interpolation (bilinear) 
var_path = 'vars_'+str(widthCell)
var_name = 'step_250'
if os.path.exists(var_path):
    shutil.rmtree(var_path)
ufcts.inter2UGRID(ncgrid,mapds,var_path,var_name,type='face')
data_ds = xr.open_dataset(var_path + '/' + var_name + '.nc')

# %% [markdown]
# In the `var_path` folder, you will find interpolated variables for the the UGRID (one file per variable)

# %%
# Extract nodes and faces information
n_nodes = mapds.dims['nCells']
ucoords = np.zeros((n_nodes, 3))
ucoords[:, 0] = mapds['xCell'].values
ucoords[:, 1] = mapds['yCell'].values
ucoords[:, 2] = mapds['zCell'].values
ufaces = mapds['cellsOnVertex'].values - 1 
print(f"Number of nodes: {len(ucoords)} | Number of faces: {len(ufaces)}")

# Get information about your mesh:
dcEdge = mapds['dcEdge'].values  # in metres
edge_min = np.round(dcEdge.min() /1000.+0.,2)
edge_max = np.round(dcEdge.max() /1000.+0.,2)
edge_mean = np.round(dcEdge.mean() /1000.+0.,2)
print("edge range (km): min ",edge_min," | max ",edge_max," | mean ",edge_mean)

# %% [markdown]
# Save voronoi mesh for visualisation purposes

# %% [markdown]
# `get_Tectonic` advects the current elevation along the plate velocities and compares it to the next paleo-elevation (`next_h`) to back out the **vertical tectonic uplift/subsidence rate** `tec` needed over the interval `dt`. The result `mesher` carries the interpolated fields plus this derived forcing.
#
# | Parameter | Symbol | Value | Physical meaning |
# | --------- | ------ | ----- | ---------------- |
# | `dt` | $\Delta t$ | $10^6$ | Time interval between the two paleo-maps, in years |
# | `zkeys` | $z, z_{t+\Delta t}$ | `['h','next_h']` | Current and next-step elevation fields |
# | `vkeys` | $\mathbf{v}$ | `['vx','vy','vz']` | Horizontal plate-velocity components (m/yr) |
# | `dkey` | – | `None` | Optional dynamic-topography field; if set, `tec` combines tectonics and dynamic topography |
# | `mthd` | – | `'IDW'` | Interpolation method (inverse-distance weighting) |

# %%
# Save voronoi mesh for visualisation purposes
saveVoro = False

if saveVoro:
    from mpas_tools.viz.paraview_extractor import extract_vtk
    extract_vtk(
            filename_pattern=ufile,
            variable_list='areaCell',
            dimension_list=['maxEdges=','nVertLevels=', 'nParticles='], 
            mesh_filename=ufile,
            out_dir=input_path, 
            ignore_time=True,
            # lonlat=True,
            xtime='none'
        )
    print("You could now visualise in Paraview (wireframe) the produced voronoi mesh!")
    print("This is a vtp mesh called: ", input_path+'/staticFieldsOnCells.vtp')

# %% [markdown]
# > You might want to check that everything went according to plan and look at the mesh and variables that will be used in goSPL.
#
# To do so, we will build a `vtk` file that could be visualised in Paraview...

# %%
checkMesh = True

if checkMesh:
    import meshio

    paleovtk = input_path+"/init.vtk"

    vlist = list(data_ds.keys())
    vdata = []
    for k in vlist:
        vdata.append(data_ds[k].values)

    list_data = dict.fromkeys(el for el in vlist)
    list_data.update((k, vdata[i]) for i, k in enumerate(list_data))

    # Define mesh
    vis_mesh = meshio.Mesh(ucoords, {"triangle": ufaces}, 
                           point_data = list_data,
                        )
    # Write it disk
    meshio.write(paleovtk, vis_mesh)
    print("Writing VTK input file as {}".format(paleovtk))

# %% [markdown]
# ## Extracting vertical tectonic forcing from successive paleo-elevation maps
#
# In case where you want to run a model with horizontal displacement rates then you could choose to adjust the tectonic forcing based on next time step paleo-elevation.
#
# To illustrate how this could be done we will use the `netcdf` grids provided in the data folder (*i.e.* 250.nc and 251.nc).

# %% [markdown]
# ## Outputs and next steps
#
# You have now generated everything `gospl` needs for this global plate-motion scenario:
#
# - **`vars_30/mesh.npz`** — node coordinates `v`, face connectivity `c`, and initial elevation `z`.
# - **`vars_30/forcing250.npz`** — plate displacement rates `vxyz` (m/yr), vertical tectonic forcing `t` (m/yr), and precipitation `r` (m/yr). Uncomment `nz` to also store the next-step elevation, which lets `gospl` nudge selected regions toward the target paleo-elevation via the `zfit` parameter.
# - **`input_30/init.vtk`** — a Paraview-ready snapshot to visually confirm the mesh and interpolated fields look correct before launching a run.
#
# Point your `gospl` YAML input file at these `.npz` paths to run the simulation, where the stream-power law $E = K A^m S^n$ and hillslope diffusion $\partial z/\partial t = \kappa \nabla^2 z + U$ are solved on this mesh while the plate velocities advect the surface.

# %%
# Loading the nc files
ncgrid_250 = xr.open_dataset('data/250.nc')
ncgrid_251 = xr.open_dataset('data/251.nc')

# Store next elevation as a new variable in the grid to interpolate
ncgrid_250 = ncgrid_250[['h','vx','vy','vz','rain']]
ncgrid_250['next_h'] = ncgrid_251['h']
ncgrid_250

# %% [markdown]
# Similar to what was done before we interpolate the structured variables to the UGRID mesh:

# %%
# Loading the UGRID file
ufile = input_path+'/mesh_'+str(widthCell)+'km.nc'
mapds = xr.open_dataset(ufile) 

# Perform the interpolation (bilinear) 
var_path = 'vars_'+str(widthCell)
var_name = 'step_up_250'
ufcts.inter2UGRID(ncgrid_250,mapds,var_path,var_name,type='face')

# %% [markdown]
# We then extract the tectonic forcing based on the displacement rates:

# %%
data_file = [var_path+'/'+var_name+'.nc']

dt = 1.e6
zkeys = ['h','next_h']
vkeys = ['vx','vy','vz']
# If you have a dynamic topography variable you can specify its corresponding key here for example dkey = ['dynt'] 
dkey = None

mesher = ufcts.get_Tectonic(ufile, *data_file, vkeys, zkeys, dkey, dt, mthd='IDW')

# %% [markdown]
# > In case where you have specified a dynamic topography variable, your tectonic variable `tec` is a combination of the tectonic and dynamic topography components.
#
# ## goSPL input generation
#
# We will now create the inputs for goSPL. We first start by creating the input mesh defining our UGRID structure:

# %%
meshname = var_path+"/mesh"
np.savez_compressed(meshname, v=ucoords, c=ufaces, 
                    z=mesher.h.data
                    )

# %% [markdown]
# Now we save the forcing conditions (displacement rates, tectonic, precipitation...). Here you have the option to also add the next time step elevation, this will then be used in goSPL to force the model to match with the next paleo-elevation for specific regions (by defining the `zfit` parameter in the input file).

# %%
forcname = var_path+"/forcing250"

vel = np.zeros(ucoords.shape)
vel[:,0] = mesher.vx.data
vel[:,1] = mesher.vy.data
vel[:,2] = mesher.vz.data
np.savez_compressed(forcname, 
                    vxyz=vel, 
                    t=mesher.tec.data, 
                    r=mesher.rain.data,
                    # nz=mesher.next_h.data,
                    )
